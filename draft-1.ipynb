# %% [markdown]
# # ARIMA-GAM COMPARISON

# %% [markdown]
# ---
# ### Overview
#
# #### Primary goal
# - covid intro
# - ny-covid
# - comparison on zcta
# - models
#     - Compare two time-series models (arima & gam)
#     - which model was best for the task of forecasting infection growth rate w/zcta
#
# #### Secondary goal
# - observations on differences between categorized zctas (income? race? pop density? mix?)
# ---

# %% [markdown]
# ---
# ### Data
# - NYC Dept of Health (covid-zcta)
# - census data (income? race? pop density?)
# ---

# %% [markdown]
# ---
# ### Tools
#
# - Python and R
#     - pandas
#     - geopandas
#     - numpy
#     - tidyverse
#     - forecast
#     - prophet
# ---

# %% [markdown]
# ---
# ### Methods / Models
#
# #### ARIMA
#
# - what is an arima model?
#
# #### GAM
#
# - what is a gam model?
# ---

# %% [markdown]
# ---
# ### Results and Comparisons
#
# #### ARIMA
#
# - pros/cons
#
# #### GAM
#
# - pros/cons
# ---

# %% [markdown]
# ---
# ### Categorized ZCTA Observations
#
# - zctas
# - observations
# ---
